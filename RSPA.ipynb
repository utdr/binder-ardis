# %%
import pandas as pd

# %% [markdown]
# ## Requête de récupération des référecences bibliographiques
# ```sql
# SELECT
#  bib_refs.id,
#  bib_refs.ref_infos,
#  bib_refs.year,
#  ne3.name auteur,
#  bib_refs.old_publicity,
#  nameable_entities1.name ref_type,
#  notes.content notes,
#  nameable_entities2.name,
#  bib_referencements_types.type_id
# FROM bib_refs
# LEFT JOIN bib_referencements
# ON bib_referencements.reference_id=bib_refs.id
# LEFT JOIN bib_referencements_types
# ON bib_referencements.id = bib_referencements_types.referencement_id
# LEFT JOIN  bib_ref_ling_types
# ON bib_referencements_types.type_id = bib_ref_ling_types.id
# LEFT JOIN nameable_entities as nameable_entities1
# ON bib_ref_ling_types.ref_type_id = nameable_entities1.id
# LEFT JOIN commentable_entities_notes
# ON bib_refs.id = commentable_entities_notes.entity_id
# LEFT JOIN notes
# ON commentable_entities_notes.note_id = notes.id
# LEFT JOIN nameable_entities as nameable_entities2
# ON bib_refs.id = nameable_entities2.id
# LEFT JOIN bib_ranked_authors
# ON bib_ranked_authors.reference_id = bib_refs.id
# LEFT JOIN nameable_entities as ne3
# ON bib_rankend_authors.author_id = ne3.id
# -- ne pas mettre cette condition si on veut aussi les refs non exportables
# -- WHERE bib_refs.old_publicity = 1
# WHERE bib_refs.ref_infos is not NULL
# ORDER BY bib_refs.year;
# ```

# %%
df = pd.read_csv("../PROJETS/RSPA/ref_biblio_all.csv")
df.fillna("", inplace=True)

def convert_to_int(x):
    return (int(x) if x else "")

df.year = df.year.apply(convert_to_int)
df.old_publicity = df.old_publicity.apply(convert_to_int)

df.rename(columns={'ref_infos': 'publication',
                   'ref_type.1': 'titre'},
          inplace=True, errors='raise')

df = df[["id","titre","auteur","year","publication","ref_type","notes","old_publicity"]]

df.head()
# Out:
#                                          id  \
# 0  00041d507b2d742fd713b80828e2189f4cf3351c
# 1  001be92168018fcd37606ddc2f33426cfbe61574
# 2  003229cbcccc97401cd119ea27558bea12cbb837
# 3  003229cbcccc97401cd119ea27558bea12cbb837
# 4  003229cbcccc97401cd119ea27558bea12cbb837
#
#                                                titre                auteur  \
# 0  Organon. 4, Seconds analytiques / Aristote; in...     Pellegrin, Pierre
# 1  Rethinking early greek philosophy: Hippolytus ...    Osborne, Catherine
# 2  [Fragments et témoignages] / Les cosmogonies o...     Raven, John Earle
# 3  [Fragments et témoignages] / Les cosmogonies o...  De Weck, Hélène-Alix
# 4  [Fragments et témoignages] / Les cosmogonies o...    Schofield, Malcolm
#
#    year                                        publication    ref_type  \
# 0  2005  Paris: Flammarion, 2005, 432 p. Coll. « GF », ...  traduction
# 1  1987              Londres: Duckworth, 1987, viii-383 p.
# 2  1995  Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...     édition
# 3  1995  Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...     édition
# 4  1995  Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...     édition
#
#                                                notes old_publicity
# 0  Suit principalement l’édition de W.D. Ross, n°...             1
# 1  Pour Hippolyte, suit principalement l’édition ...             1
# 2                                                                1
# 3                                                                1
# 4                                                                1

# %%
df.shape
# Out:
# (14922, 8)

# %%
len(df.id.unique())
# Out:
# 6194

# %%
df_grouped_authors = df.groupby(['id'])['auteur'].apply(lambda x: '/'.join(x)).reset_index()

# %%
df_grouped_authors.shape
# Out:
# (6194, 2)

# %%
df_grouped_types = df.groupby(['id'])['ref_type'].apply(lambda x: ', '.join(x)).reset_index()

# %%
df_grouped_types.shape
# Out:
# (6194, 2)

# %%
df_grouped_types.head(10)
# Out:
#                                          id  \
# 0  00041d507b2d742fd713b80828e2189f4cf3351c
# 1  001be92168018fcd37606ddc2f33426cfbe61574
# 2  003229cbcccc97401cd119ea27558bea12cbb837
# 3  0048b30b02159daed1bd2cd8b0f10161f7edf8ac
# 4  0049009ae4af035b08310cef4930fe673e5e91a1
# 5  004a25aef1a854c52131848c7ff3f3df3b8bd9fb
# 6  005b35c41de3903d386ab1348fdc18ffb1d3da73
# 7  00846a34a52093e0ce0b732590dde683fb43c44f
# 8  009760968578745831843715565036faabb62ad9
# 9  00aea3c021babdada6fada757f4480cd54e6e328
#
#                                             ref_type
# 0                                         traduction
# 1
# 2  édition, édition, édition, édition, édition, c...
# 3                                édition, traduction
# 4                                         traduction
# 5                                édition, traduction
# 6                                   édition critique
# 7                               édition, commentaire
# 8                                   édition critique
# 9                                édition, traduction

# %%
def reduce_types(x):
    return ",".join(set(map(str.strip,x.split(','))))
test = "édition, traduction, édition, commentaire"
reduce_types(test)

def reduce_authors(x):
    return "/".join(set(map(str.strip,x.split('/'))))

# %%
df_grouped_types["concat_ref_types"] = df_grouped_types.ref_type.apply(reduce_types)

# %%
df_grouped_authors["concat_authors"] = df_grouped_authors.auteur.apply(reduce_authors)

# %%
df_grouped_types.tail()
# Out:
#                                             id  \
# 6189  ff7f04c037603086417d5cdf57c471753e003b39
# 6190  ff97e7e246ef7f75cca9ca5f7e37714d6a3fcfc4
# 6191  ffc3418c40391b4462c5706cdc7b0cc5493e0584
# 6192  ffeb9822d72c69179f86dd5c2e7d864e9469de7c
# 6193  ffef7b3b07e80e945f0ce4aa8cdaff4b476825f4
#
#                                 ref_type     concat_ref_types
# 6189              traduction, traduction           traduction
# 6190                    édition critique     édition critique
# 6191  édition critique, édition critique     édition critique
# 6192  édition critique, édition critique     édition critique
# 6193                édition, commentaire  édition,commentaire

# %%
df_grouped_authors.tail()
# Out:
#                                             id  \
# 6189  ff7f04c037603086417d5cdf57c471753e003b39
# 6190  ff97e7e246ef7f75cca9ca5f7e37714d6a3fcfc4
# 6191  ffc3418c40391b4462c5706cdc7b0cc5493e0584
# 6192  ffeb9822d72c69179f86dd5c2e7d864e9469de7c
# 6193  ffef7b3b07e80e945f0ce4aa8cdaff4b476825f4
#
#                                            auteur  \
# 6189  Morand,  Anne-France/Lukinovich, Alessandra
# 6190                                 Meiser, Karl
# 6191              Bernabé, Alberto/Olmos, Ricardo
# 6192                 Gigon, Olof/Bekker, Immanuel
# 6193              Marx, Friedrich/Marx, Friedrich
#
#                                    concat_authors
# 6189  Lukinovich, Alessandra/Morand,  Anne-France
# 6190                                 Meiser, Karl
# 6191              Bernabé, Alberto/Olmos, Ricardo
# 6192                 Bekker, Immanuel/Gigon, Olof
# 6193                              Marx, Friedrich

# %%
df.drop(['auteur', 'ref_type'], axis = 1, inplace = True)

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df.shape
# Out:
# (6194, 6)

# %%
df.head()
# Out:
#                                           id  \
# 0   00041d507b2d742fd713b80828e2189f4cf3351c
# 1   001be92168018fcd37606ddc2f33426cfbe61574
# 2   003229cbcccc97401cd119ea27558bea12cbb837
# 17  0048b30b02159daed1bd2cd8b0f10161f7edf8ac
# 19  0049009ae4af035b08310cef4930fe673e5e91a1
#
#                                                 titre  year  \
# 0   Organon. 4, Seconds analytiques / Aristote; in...  2005
# 1   Rethinking early greek philosophy: Hippolytus ...  1987
# 2   [Fragments et témoignages] / Les cosmogonies o...  1995
# 17  Plato. 2, Laches ; Protagoras ; Meno ; Euthyde...  1990
# 19             [Fragmenta et testimonia] / Bro(n)tino  1969
#
#                                           publication  \
# 0   Paris: Flammarion, 2005, 432 p. Coll. « GF », ...
# 1               Londres: Duckworth, 1987, viii-383 p.
# 2   Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...
# 17  Cambridge (Mass.); Londres:: Harvard universit...
# 19       Cf. G. Giannantoni, n° [[49]], I, p. 134-135
#
#                                                 notes old_publicity
# 0   Suit principalement l’édition de W.D. Ross, n°...             1
# 1   Pour Hippolyte, suit principalement l’édition ...             1
# 2                                                                 1
# 17  Texte grec et trad. anglaise en regard. - Bibl...
# 19                                                                1

# %%
df1 = pd.merge(df, df_grouped_authors, how="inner", on="id")

# %%
df1.shape
# Out:
# (6194, 8)

# %%
df_final = pd.merge(df1, df_grouped_types, how="inner", on="id")

# %%
df_final.shape
# Out:
# (6194, 10)

# %%
df_final.head()
# Out:
#                                          id  \
# 0  00041d507b2d742fd713b80828e2189f4cf3351c
# 1  001be92168018fcd37606ddc2f33426cfbe61574
# 2  003229cbcccc97401cd119ea27558bea12cbb837
# 3  0048b30b02159daed1bd2cd8b0f10161f7edf8ac
# 4  0049009ae4af035b08310cef4930fe673e5e91a1
#
#                                                titre  year  \
# 0  Organon. 4, Seconds analytiques / Aristote; in...  2005
# 1  Rethinking early greek philosophy: Hippolytus ...  1987
# 2  [Fragments et témoignages] / Les cosmogonies o...  1995
# 3  Plato. 2, Laches ; Protagoras ; Meno ; Euthyde...  1990
# 4             [Fragmenta et testimonia] / Bro(n)tino  1969
#
#                                          publication  \
# 0  Paris: Flammarion, 2005, 432 p. Coll. « GF », ...
# 1              Londres: Duckworth, 1987, viii-383 p.
# 2  Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...
# 3  Cambridge (Mass.); Londres:: Harvard universit...
# 4       Cf. G. Giannantoni, n° [[49]], I, p. 134-135
#
#                                                notes old_publicity  \
# 0  Suit principalement l’édition de W.D. Ross, n°...             1
# 1  Pour Hippolyte, suit principalement l’édition ...             1
# 2                                                                1
# 3  Texte grec et trad. anglaise en regard. - Bibl...
# 4                                                                1
#
#                                               auteur  \
# 0                                  Pellegrin, Pierre
# 1                                 Osborne, Catherine
# 2  Raven, John Earle/De Weck, Hélène-Alix/Schofie...
# 3  Lamb, Walter Rangeley Maitland/Lamb, Walter Ra...
# 4                                 Maddalena, Antonio
#
#                                       concat_authors  \
# 0                                  Pellegrin, Pierre
# 1                                 Osborne, Catherine
# 2  De Weck, Hélène-Alix/Raven, John Earle/O’Meara...
# 3                     Lamb, Walter Rangeley Maitland
# 4                                 Maddalena, Antonio
#
#                                             ref_type  \
# 0                                         traduction
# 1
# 2  édition, édition, édition, édition, édition, c...
# 3                                édition, traduction
# 4                                         traduction
#
#                  concat_ref_types
# 0                      traduction
# 1
# 2  édition,traduction,commentaire
# 3              édition,traduction
# 4                      traduction

# %%
df_final.drop(["auteur", "ref_type"], axis=1, inplace=True)

# %%
df_final.head()
# Out:
#                                          id  \
# 0  00041d507b2d742fd713b80828e2189f4cf3351c
# 1  001be92168018fcd37606ddc2f33426cfbe61574
# 2  003229cbcccc97401cd119ea27558bea12cbb837
# 3  0048b30b02159daed1bd2cd8b0f10161f7edf8ac
# 4  0049009ae4af035b08310cef4930fe673e5e91a1
#
#                                                titre  year  \
# 0  Organon. 4, Seconds analytiques / Aristote; in...  2005
# 1  Rethinking early greek philosophy: Hippolytus ...  1987
# 2  [Fragments et témoignages] / Les cosmogonies o...  1995
# 3  Plato. 2, Laches ; Protagoras ; Meno ; Euthyde...  1990
# 4             [Fragmenta et testimonia] / Bro(n)tino  1969
#
#                                          publication  \
# 0  Paris: Flammarion, 2005, 432 p. Coll. « GF », ...
# 1              Londres: Duckworth, 1987, viii-383 p.
# 2  Cf. G. S. Kirk, J. E. Raven, M. Schofield, H.-...
# 3  Cambridge (Mass.); Londres:: Harvard universit...
# 4       Cf. G. Giannantoni, n° [[49]], I, p. 134-135
#
#                                                notes old_publicity  \
# 0  Suit principalement l’édition de W.D. Ross, n°...             1
# 1  Pour Hippolyte, suit principalement l’édition ...             1
# 2                                                                1
# 3  Texte grec et trad. anglaise en regard. - Bibl...
# 4                                                                1
#
#                                       concat_authors  \
# 0                                  Pellegrin, Pierre
# 1                                 Osborne, Catherine
# 2  De Weck, Hélène-Alix/Raven, John Earle/O’Meara...
# 3                     Lamb, Walter Rangeley Maitland
# 4                                 Maddalena, Antonio
#
#                  concat_ref_types
# 0                      traduction
# 1
# 2  édition,traduction,commentaire
# 3              édition,traduction
# 4                      traduction

# %%
df_final.to_csv("export_ref_biblio_6194.csv", sep=";", encoding="utf-8", index=False)
